# %%
from bs4 import BeautifulSoup as soup
import requests
from urllib.request import urlopen

# %%
import pandas as pd
import numpy as np

# %%
import csv
from selenium import webdriver

# %%
keyword=input("Enter product to search: ")
# Out:
# Enter product to search: hppavillion

# %%
url="https://www.flipkart.com/search?q="+keyword
urlA="https://www.amazon.in/s?k="+keyword

# %% [markdown]
# ## Amazon

# %%
def scrape(urlM):
    if urlM==urlA:
        driver=webdriver.Chrome(executable_path="C:\webdrivers\chromedriver.exe")
        driver.get(urlA)
        page_soupA=soup(driver.page_source,"html.parser")
        #print(page_soupA)
        containerA=page_soupA.find_all('div',{'data-component-type':"s-search-result"})
        conA=containerA[0]
        soup.prettify(conA)
        print("-------------------------------------------------")

        for co in containerA:
            atag=co.h2.a
            print(atag.text)
        print("-------------------------------------------------")

        for pr in containerA:
                prA=pr.find('span','a-price')

                try:
                    priceA=prA('span','a-offscreen')
                    print(priceA[0].text)

                except(TypeError):
                    print()
        print("-------------------------------------------------")

        for rat in containerA:
            try:
                rating=rat.i.text
                print(rating)
            except(AttributeError):
                print()

        print("-------------------------------------------------")
        for rew in containerA:
            try:
                rewC=rew.find('span',{'class':"a-size-base s-underline-text"})
                print(rewC.text)
            except(AttributeError):
                print()
    elif urlM==url:
        uClient=urlopen(url)
        page_html=uClient.read()
        uClient.close()
        page_soup=soup(page_html,"html.parser")
        container=page_soup.find_all("div",{"class":"_2kHMtA"})
        con=container[0]
        soup.prettify(con)
        print("-------------------------------------------------")

        for co in container:
            product_name=co.findAll("div",{"class":"_4rR01T"})
            print(product_name[0].text)
        print("-------------------------------------------------")

        for co in container:
            s_price=co.findAll("div",{"class":"_30jeq3 _1_WHN1"})
            print(s_price[0].text)
        print("-------------------------------------------------")

        for co in container:
            rating=co.findAll("span",{"class":"_2_R_DZ"})
            try:
                 print(rating[0].text)
            except(IndexError):
                print()
        print("-------------------------------------------------")

        for co in container:
            star=co.findAll("div",{"class":"_3LWZlK"})
            try:
                print(star[0].text)
            except(IndexError):
                print()

keyword=input("Enter product to search: ")
keyword=keyword.replace(" ","+")

url="https://www.flipkart.com/search?q="+keyword
urlA="https://www.amazon.in/s?k="+keyword


print("Connecting to amazon")
scrape(urlA)
print("Connecting to Flipkart")
scrape(url)
# Out:
# Enter product to search: hp omen
# Connecting to amazon
# <ipython-input-76-af8c972369dc>:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path="C:\webdrivers\chromedriver.exe")
# -------------------------------------------------
# Hp Victus Latest AMD Ryzen 5 5600H Processor 16.1 Inches Fhd Gaming Laptop (8Gb Ram/512 Gb Ssd/144 Hz/Geforce GTX 1650/Alexa/B&O/Backlit Keyboard, Windows 11 Home, /Ms Office),16-E0301Ax, Mica Silver
# HP Victus 11th Gen Intel Core i7-11800H 16.1" FHD Gaming Laptop (16GB RAM/512GB SSD/144 Hz/300 nits/7 ms Response time/GeForce RTX 3060 6GB Graphics/Backlit KB/Win11/MSO) 16-d0361TX Performance Blue
# Hp Omen 11Th Gen Intel Core I7-11800H 16.1 Inches (40.9 cm) Fhd Flicker-Free Gaming Laptop (16Gb/1Tb Ssd/144 Hz/RTX 3060 6Gb Graphics/Windows 11/Ms Office/2.32Kg/ Shadow Black), 16-B0360Tx
# Hp Omen AMD Ryzen 5 16.1-Inch(40.9 cm) Micro-Edge, IPS, Anti-Glare, Fhd Gaming Laptop (8Gb Ram/512 Gb Ssd/144 Hz/Geforce GTX 1650 Graphics/Alexa/Windows 11/Ms Office),16-C0136Ax, Mica Silver
# HP OMEN 15.6 inches FHD Gaming Laptop (AMD Ryzen 7-5800H/16GB/1TB SSD/144Hz Refresh Rate/Windows 10 Home/NVIDIA RTX 3060 6GB/Shadow Black/2.36Kg), 15-en1036AX
# OMEN by HP-12th Gen Intel i7 16.1-inch(40.9 cm) QHD Gaming Laptop (16GB DDR5 RAM/1TB Gen 4 SSD/165 Hz/300 nits/RTX 3070/4 Zone KB Backlight/Max 115W TGP/Win 11/MSO/Xbox Game Pass(30 Days)),16-B1370TX
# HP OMEN AMD Ryzen 5-4600H 15.6 inches FHD Screen Gaming Laptop, 8 GB DDR6 RAM, 4GB NVIDIA 1650ti Graphics, 512 GB SSD, Windows 10 Home with Advanced Thermal Management, 2.36kg, 15-en0001AX
# Hp Omen AMD Ryzen 7 16.1 Inches (40.9 cm) Micro-Edge, IPS, Anti-Glare, Fhd Gaming Laptop (16Gb Ram/512Gb Ssd/144 Hz/300 Nits/Geforce RTX 3050Ti Graphics/Windows 11 Home/Ms Office),16-C0138Ax, Silver
# HP OMEN 10th Gen Intel Core i5 Processor 15.6-inch FHD Gaming Laptop (i5-10300H/8GB/1TB SSD/Windows 10/NVIDIA GTX 1650ti 4GB/Shadow Black/2.36 kg), 15-ek0017TX
# HP Omen X 2S Intel Core i7 9th Gen 15.6 inches Dual Screen Full HD, LED Gaming Laptop (16GB/1TB SSD/Windows 10/8GB NVIDIA RTX 2080 Graphics/Shadow Black, 2.34 kg) 15-dg0018TX
# HP Pavilion Gaming 11th Gen Intel Core i5 15.6 inch(39.6 cm) FHD Gaming Laptop (8GB RAM/256GB SSD+1TB HDD/144Hz/GTX 1650 4GB Graphics/Windows 10/MS Office/Shadow Black/2.28 Kg), 15-dk2100TX
# Hp Victus Latest AMD Ryzen 5 5600H Processor 16.1 Inches Fhd Gaming Laptop (8Gb Ram/512Gb Ssd/4Gb Radeon Rx5500M Graphics/Flicker Free Display/B&O/Backlit Kb/Windows 10 Home/Ms Office), 16-E0162Ax
# HP Omen Intel Core i7 9th Gen 15.6 inches FHD, LED Gaming Laptop (16GB/1TB HDD + 512GB SSD/Windows 10/NVIDIA RTX 2070 8GB Graphics/Shadow Black, 2.9 kg) 15-dh0138TX
# HP OMEN 15.6 inches QHD Gaming Laptop (AMD Ryzen 7-5800H/16GB/1TB SSD/165Hz Refresh Rate/Windows 10 Home/NVIDIA RTX 3070 8GB/Shadow Black/2.36Kg), 15-en1037AX
# HP OMEN AMD Ryzen 7-4800H 15.6 inches FHD Gaming Laptop (16GB/1TB SSD/Windows 10 Home/NVIDIA RTX 2060 6GB/Shadow Black/2.37Kg), 15-en0037ax
# HP OMEN 10th Gen Intel Core i7 Processor 15.6" (39.62cms) FHD Gaming Laptop (i7-10750H/16GB/1TB SSD/Windows 10/300 Nits/144 Hz/NVIDIA GTX 1650ti 4GB/Shadow Black/2.36 kg), 15-ek0019TX
# HP OMEN 10th Gen Intel Core i7 Processor 15.6" (39.62cms) FHD Gaming Laptop (i7-10750H/16GB/512GB SSD/Windows 10/NVIDIA RTX 2060 6GB/Shadow Black/2.36 kg), 15-ek0042TX
# OMEN by HP-12th Gen Intel i7 16.1-inch(40.9 cm) QHD Gaming Laptop (16GB DDR5 RAM/1TB Gen 4 SSD/165 Hz/300 nits/RTX 3070 Ti /4 Zone KB Backlight/Max 115W TGP/Win 11/Xbox Game Pass(30 Days)),16-B1371TX
# OMEN by HP-Ryzen 7 16.1-inch(40.9 cm) Micro-Edge, IPS, Anti-Glare, FHD Gaming Laptop (16GB RAM/1TB SSD/144 Hz/300 nits/Radeon RX 6600M Graphics/Win 11/MS Office),16-C0140AX, Silver
# Hp Omen AMD Ryzen 9 16.1 Inches Micro-Edge IPS Anti-Glare Qhd Gaming Laptop (16Gb Ram/1Tb Ssd/300 Nits/Rx 6600M 8 Gb Graphics/B&O Audio/Backlit Keyboard/Windows 11 Home/Ms Office), 16-C0141Ax, Silver
# Fujitsu CH Intel Evo Core i5 11th Gen 13.3” FHD OLED 400Nits Thin & Light Laptop(16GB/512GB SSD/Windows 11/Office 2021/Iris Xe Graphics/Backlit/2Yr Warranty/Dark Grey/1.1Kg),4ZR1H03552
# Fujitsu UH-X 11th Gen Intel Core i7 13.3” FHD IPS 400Nits Thin & Light Laptop(16GB/512GB SSD/Windows 11/Office 2021/Iris Xe Graphics/Backlit Kb/Fingerprint Reader/2Yr Warranty/Black/878gms),4ZR1F38024
# -------------------------------------------------
# ₹65,990
# ₹1,22,427
# ₹1,34,090
# ₹78,906
# ₹1,17,500
# ₹1,63,990
# ₹86,000
# ₹1,00,118
# ₹91,500
# ₹2,68,000
# ₹66,990
# ₹61,490
# ₹1,60,000
# ₹1,53,000
#
# ₹1,23,700
# ₹1,35,990
# ₹1,70,990
# ₹1,15,400
# ₹1,29,899
# ₹73,990
# ₹81,590
# -------------------------------------------------
# 4.3 out of 5 stars
# 3.6 out of 5 stars
#
#
# 4.2 out of 5 stars
# 3.0 out of 5 stars
# 4.4 out of 5 stars
# 3.3 out of 5 stars
# 4.3 out of 5 stars
# 2.0 out of 5 stars
# 4.1 out of 5 stars
# 4.3 out of 5 stars
# 4.0 out of 5 stars
# 2.8 out of 5 stars
# 4.5 out of 5 stars
# 4.1 out of 5 stars
# 3.6 out of 5 stars
#
#
# 1.0 out of 5 stars
# 2.4 out of 5 stars
# 4.5 out of 5 stars
# -------------------------------------------------
# 676
# 5
#
#
# 9
# 1
# 342
# 3
# 87
# 4
# 43
# 534
# 41
# 5
# 4
# 42
# 10
#
#
# 1
# 9
# 58
# Connecting to Flipkart
# -------------------------------------------------
# HP OMEN 15 Ryzen 7 Octa Core 5800H - (16 GB/1 TB SSD/Windows 10 Home/6 GB Graphics/NVIDIA GeForce RTX ...
# HP OMEN Core i7 11th Gen - (16 GB/1 TB SSD/Windows 11 Home/4 GB Graphics/NVIDIA GeForce RTX RTX 3050Ti...
# HP OMEN 15 Ryzen 7 Octa Core 5800H - (16 GB/1 TB SSD/Windows 10 Home/8 GB Graphics/NVIDIA GeForce RTX ...
# HP OMEN Ryzen 5 Hexa Core 5600H - (8 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/NVIDIA GeForce GTX 16...
# HP Omen Core i7 11th Gen - (16 GB/1 TB SSD/Windows 11 Home/6 GB Graphics/NVIDIA GeForce RTX RTX 3060) ...
# HP OMEN Ryzen 7 Octa Core 5800H - (16 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/NVIDIA GeForce RTX 3...
# HP OMEN Core i7 11th Gen - (16 GB/1 TB SSD/Windows 11 Home/4 GB Graphics/NVIDIA GeForce RTX RTX 3050) ...
# HP OMEN Core i7 12th Gen - (16 GB/1 TB SSD/Windows 11 Home/4 GB Graphics) 16-B1351TX Laptop
# HP OMEN Core i7 12th Gen - (16 GB/1 TB SSD/Windows 11 Home/6 GB Graphics) 16-B1361TX Laptop
# HP Omen Core i5 7th Gen - (8 GB/1 TB HDD/128 GB SSD/Windows 10 Home/4 GB Graphics/NVIDIA GeForce GTX 1...
# HP OMEN Ryzen 9 Octa Core 5900H - (16 GB/1 TB SSD/Windows 10 Home/8 GB Graphics/AMD Radeon RX 6600M) 1...
# HP OMEN Ryzen 7 Octa Core 5800H - (16 GB/1 TB SSD/Windows 11 Home/AMD Radeon RX 6600M) 16-C0140AX Gami...
# HP Omen Ryzen 5 Hexa Core 4600H - (8 GB/512 GB SSD/Windows 10 Home/6 GB Graphics/NVIDIA GeForce GTX 16...
# HP Omen Ryzen 7 Octa Core 4800H - (8 GB/512 GB SSD/Windows 10 Home/4 GB Graphics/NVIDIA GeForce GTX 16...
# HP Omen Ryzen 5 Hexa Core 4600H - (8 GB/512 GB SSD/Windows 10 Home/4 GB Graphics/NVIDIA GeForce GTX 16...
# HP 1000 Wired Optical Mouse
# PHILIPS HP8100/46 Hair Dryer
# PHILIPS HP8302/06 Hair Straightener
# PHILIPS HP8100/60 Hair Dryer
# HP 100 Wired USB Desktop Keyboard
# ZEBRONICS Zeb-Judwaa 750 Keyboard & Mouse Combo Wired USB Desktop Keyboard
# DELL KB 216 Wired USB Desktop Keyboard
# ZEBRONICS ZEB-KM-2100 Wired USB Desktop Keyboard
# HP C2500 Wired Combo keyboard and Mouse
# HP JDBAG00007 15.6 L Laptop Backpack
# KRAFTER Latest Collection Casual Boots For girls High heel Partywear Shoes For Ladies Boots For Women
# HP hkih4432 Waterproof Backpack
# HP Gold Perfume 100ML Each (Pack of 2) Eau de Parfum  -  200 ml
# RAPOO N100 Wired Optical Mouse
# AMKETTE 398PP, Xcite NEO Wired USB Laptop Keyboard
# PHILIPS HP6388/00 Trimmer 60 min  Runtime 2 Length Settings
# Razer Death Adder Essential Wired Optical  Gaming Mouse
# Half Moon Waterproof Laptop Backpack Bag with Rain Cover 35 L Laptop Backpack
# PHILIPS HP8643/46 Hair Straightener + Hair Dryer
# ZEBRONICS JUDWAA 555 Combo Mouse and Wired USB Laptop Keyboard
# HINDVA FASHION Women Embellished A-line Kurta
# HP Value Backpack for Laptops upto 17.3-inch 15.55 L Laptop Backpack
# Jaipur Sarai Women Printed Straight Kurta
# HINDVA FASHION Women Embellished A-line Kurta
# Carriway Storm Buster CRW10 30 L Laptop Backpack
# -------------------------------------------------
# ₹1,09,990
# ₹1,18,490
# ₹1,58,490
# ₹79,690
# ₹1,34,090
# ₹1,22,804
# ₹1,32,717
# ₹1,44,128
# ₹1,55,490
# ₹1,02,551
# ₹1,39,980
# ₹1,25,500
# ₹85,949
# ₹85,949
# ₹75,949
# ₹239
# ₹705
# ₹1,125
# ₹707
# ₹449
# ₹524
# ₹569
# ₹329
# ₹918
# ₹409
# ₹299
# ₹399
# ₹449
# ₹189
# ₹529
# ₹1,170
# ₹1,359
# ₹699
# ₹1,922
# ₹465
# ₹449
# ₹755
# ₹299
# ₹449
# ₹599
# -------------------------------------------------
# 543 Ratings & 68 Reviews
#
# 18 Ratings & 2 Reviews
#
#
#
#
#
#
#
#
#
# 436 Ratings & 69 Reviews
# 156 Ratings & 38 Reviews
# 865 Ratings & 141 Reviews
# 42,541 Ratings & 5,298 Reviews
# 2,70,259 Ratings & 28,902 Reviews
# 85,909 Ratings & 7,658 Reviews
# 2,70,259 Ratings & 28,902 Reviews
# 10,341 Ratings & 1,402 Reviews
# 8,533 Ratings & 1,017 Reviews
# 18,886 Ratings & 2,769 Reviews
# 12,499 Ratings & 1,686 Reviews
# 28,202 Ratings & 4,020 Reviews
# 17,699 Ratings & 2,153 Reviews
# 7,505 Ratings & 1,169 Reviews
# 13,363 Ratings & 1,200 Reviews
# 525 Ratings & 82 Reviews
# 392 Ratings & 76 Reviews
# 15,914 Ratings & 2,655 Reviews
# 2,564 Ratings & 205 Reviews
# 2,356 Ratings & 283 Reviews
# 1,497 Ratings & 156 Reviews
# 45,395 Ratings & 5,388 Reviews
# 10,445 Ratings & 1,516 Reviews
# 1,040 Ratings & 119 Reviews
# 80 Ratings & 3 Reviews
# 84 Ratings & 15 Reviews
# 1,040 Ratings & 119 Reviews
# 586 Ratings & 56 Reviews
# -------------------------------------------------
# 4.5
#
# 4.8
#
#
#
#
#
#
#
#
#
# 4.7
# 4.7
# 4.5
# 4.3
# 4.3
# 4.2
# 4.3
# 4.4
# 4.1
# 4.4
# 4
# 4.3
# 3.9
# 4.3
# 3.9
# 4.3
# 4.3
# 4.2
# 4
# 4.5
# 4
# 4.3
# 4
# 4.2
# 4.3
# 4.3
# 4.2
# 4.2

# %% [markdown]
# ## Flipkart

# %%
uClient=urlopen(url)
page_html=uClient.read()
uClient.close()
page_soup=soup(page_html,"html.parser")
container=page_soup.find_all("div",{"class":"_2kHMtA"})
con=container[0]
soup.prettify(con)
print("-------------------------------------------------")

for co in container:
    product_name=co.findAll("div",{"class":"_4rR01T"})
    print(product_name[0].text)
print("-------------------------------------------------")

for co in container:
    s_price=co.findAll("div",{"class":"_30jeq3 _1_WHN1"})
    print(s_price[0].text)
print("-------------------------------------------------")

for co in container:
    rating=co.findAll("span",{"class":"_2_R_DZ"})
    try:
         print(rating[0].text)
    except(IndexError):
        print()
print("-------------------------------------------------")

for co in container:
    star=co.findAll("div",{"class":"_3LWZlK"})
    try:
        print(star[0].text)
    except(IndexError):
        print()
# Out:
# -------------------------------------------------
# HP Pavilion Ryzen 5 Hexa Core 5600H - (8 GB/512 GB SSD/Windows 10/4 GB Graphics/NVIDIA GeForce GTX 165...
# HP Pavilion Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/Windows 10 Home) 14-ec0035AU Thin and Light Lap...
# HP Pavilion Core i5 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) 14-dv1000TU Thin and Light Laptop
# HP Pavilion Core i5 12th Gen - (16 GB/512 GB SSD/Windows 11 Home) EG2036TU Thin and Light Laptop
# HP Pavilion Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/Windows 10 Home) 15-eh1101AU Thin and Light Lap...
# HP Pavilion Core i5 12th Gen - (8 GB/512 GB SSD/Windows 11 Home) 15-EG2009TU Thin and Light Laptop
# HP Pavilion Core i5 11th Gen - (16 GB/512 GB SSD/Windows 11 Home) 14-dv1001TU Thin and Light Laptop
# HP Pavilion Core i7 12th Gen - (16 GB/1 TB SSD/Windows 11 Home) EG2039TU Thin and Light Laptop
# HP Pavilion Ryzen 5 Hexa Core 5625U - (8 GB/512 GB SSD/Windows 11 Home) 14-EC1003AU Thin and Light Lap...
# HP Pavilion Core i5 12th Gen - (16 GB/512 GB SSD/Windows 11 Home) EG2035TU Thin and Light Laptop
# HP Pavilion Ryzen 7 Octa Core 5825U - (16 GB/512 GB SSD/Windows 11 Home) 14-EC1008AU Thin and Light La...
# HP Pavilion Ryzen 5 Hexa Core 5625U - (16 GB/512 GB SSD/Windows 11 Home) 14-EC1019AU Thin and Light La...
# HP Pavilion Ryzen 7 Octa Core 5800H - (16 GB/512 GB SSD/Windows 10 Home/4 GB Graphics/NVIDIA GeForce R...
# HP Pavilion Ryzen 5 Hexa Core 5625U - (16 GB/512 GB SSD/Windows 11 Home) 15-eh2024AU Thin and Light La...
# HP Pavilion Ryzen 5 Hexa Core 5600H - (8 GB/512 GB SSD/Windows 10 Home/4 GB Graphics/NVIDIA GeForce GT...
# HP Pavilion Ryzen 5 Hexa Core 5500U - (16 GB/512 GB SSD/Windows 10 Home) 15-eh1103AU Thin and Light La...
# HP Pavilion Ryzen 5 Hexa Core 5500U - (16 GB/512 GB SSD/Windows 10 Home/2 GB Graphics) 14-ec0000AX Thi...
# HP Pavilion Core i5 11th Gen - (8 GB/512 GB SSD/Windows 10 Home) 15-eg0547TU Thin and Light Laptop
# HP Pavilion Core i7 11th Gen - (16 GB/512 GB SSD/Windows 11 Home) 14-dy1050TU Thin and Light Laptop
# HP Pavilion Core i7 11th Gen - (16 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/NVIDIA GeForce RTX RTX ...
# HP Pavilion Core i5 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) 15-eg1000TU Thin and Light Laptop
# HP Pavilion Ryzen 5 Hexa Core 5500U - (16 GB/512 GB SSD/Windows 10 Home) 14-ec0033AU Thin and Light La...
# HP Pavilion Ryzen 5 Hexa Core 5600H - (8 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/NVIDIA GeForce GT...
# HP Pavilion Core i5 11th Gen - (16 GB/512 GB SSD/Windows 11 Home) 14-dy1049TU Thin and Light Laptop
# -------------------------------------------------
# ₹60,990
# ₹54,990
# ₹57,890
# ₹73,190
# ₹54,999
# ₹64,990
# ₹65,990
# ₹87,490
# ₹54,990
# ₹73,190
# ₹71,999
# ₹62,988
# ₹90,990
# ₹62,990
# ₹73,544
# ₹59,990
# ₹63,990
# ₹62,990
# ₹88,190
# ₹87,990
# ₹63,990
# ₹59,990
# ₹72,990
# ₹75,190
# -------------------------------------------------
# 6,480 Ratings & 700 Reviews
# 433 Ratings & 59 Reviews
# 134 Ratings & 11 Reviews
#
# 130 Ratings & 20 Reviews
# 5 Ratings & 1 Reviews
# 227 Ratings & 18 Reviews
#
# 5 Ratings & 3 Reviews
#
# 4 Ratings & 0 Reviews
# 4 Ratings & 1 Reviews
# 280 Ratings & 40 Reviews
#
#
# 229 Ratings & 25 Reviews
# 107 Ratings & 15 Reviews
# 4 Ratings & 0 Reviews
#
# 13 Ratings & 4 Reviews
# 25 Ratings & 1 Reviews
# 26 Ratings & 3 Reviews
# 32 Ratings & 6 Reviews
#
# -------------------------------------------------
# 4.5
# 4.4
# 4.2
#
# 4.5
# 4.2
# 4.4
#
# 4.6
#
# 4.5
# 5
# 4.6
#
#
# 4.4
# 4.2
# 4.3
#
# 4.8
# 4.3
# 4.5
# 4.5

# %%
keyword=input("Enter product to search: ")
# Out:
# Enter product to search: hp omen

# %%
keyword=keyword.replace(" ","+")
keyword
# Out:
# 'hp+omen'
