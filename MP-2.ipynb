# %%
from bs4 import BeautifulSoup as soup
import requests
from urllib.request import urlopen

# %%
import pandas as pd
import numpy as np

# %%
import csv
from selenium import webdriver

# %%
keyword=input("Enter product to search: ")
# Out:
# Enter product to search: hppavillion

# %%
url="https://www.flipkart.com/search?q="+keyword
urlA="https://www.amazon.in/s?k="+keyword

# %% [markdown]
# ## Amazon

# %%
 data={"Product_Name":[],"Price":[],"Rating":[],"Reviews":[],"Website":[]}
def scrape(urlM):
   
    if urlM==urlA:
        driver=webdriver.Chrome(executable_path="C:\webdrivers\chromedriver.exe")
        driver.get(urlA)
        page_soupA=soup(driver.page_source,"html.parser")
        #print(page_soupA)
        containerA=page_soupA.find_all('div',{'data-component-type':"s-search-result"})
        conA=containerA[0]
        soup.prettify(conA)
        print("-------------------------------------------------")

        for co in containerA[0:6]:
            atag=co.h2.a
            print(atag.text)
            data["Product_Name"].append(atag.text)
            data["Website"].append("AMAZON.IN")
        print("-------------------------------------------------")

        for pr in containerA[0:6]:
                prA=pr.find('span','a-price')

                try:
                    priceA=prA('span','a-offscreen')
                    print(priceA[0].text)
                    data["Price"].append(priceA[0].text)

                except(TypeError):
                    print()
                    data["Price"].append("NO PRICE LISTED")
        print("-------------------------------------------------")

        for rat in containerA[0:6]:
            try:
                rating=rat.i.text
                print(rating)
                data["Rating"].append(rating)
            except(AttributeError):
                print()
                data["Rating"].append("NO RATINGS")

        print("-------------------------------------------------")
        for rew in containerA[0:6]:
            try:
                rewC=rew.find('span',{'class':"a-size-base s-underline-text"})
                print(rewC.text)
                data["Reviews"].append(rewC.text)
            except(AttributeError):
                print()
                data["Reviews"].append("NO REVIEWS")
                
                
                
                
                
    elif urlM==url:
        try:
            uClient=urlopen(url)
            page_html=uClient.read()
            uClient.close()
            page_soup=soup(page_html,"html.parser")
            container=page_soup.find_all("div",{"class":"_2kHMtA"})
            con=container[0]
            soup.prettify(con)
            print("-------------------------------------------------")

            for co in container[0:6]:
                product_name=co.findAll("div",{"class":"_4rR01T"})
                print(product_name[0].text)
                data["Product_Name"].append(product_name[0].text)
                data["Website"].append("FLIPKART.COM")
            print("-------------------------------------------------")

            for co in container[0:6]:
                s_price=co.findAll("div",{"class":"_30jeq3 _1_WHN1"})
                print(s_price[0].text)
                data["Price"].append(s_price[0].text)
            print("-------------------------------------------------")

            for co in container[0:6]:

                try:
                    rating=co.findAll("span",{"class":"_2_R_DZ"})
                    print(rating[0].text)
                    data["Reviews"].append(rating[0].text)
                except(IndexError):
                    print()
                    data["Reviews"].append("NO REVIEWS")
            print("-------------------------------------------------")

            for co in container[0:6]:

                try:
                    star=co.findAll("div",{"class":"_3LWZlK"})
                    print(star[0].text)
                    data["Rating"].append(star[0].text)
                except(IndexError):
                    print()
                    data["Rating"].append("NO RATINGS")
        except:
            print("NO data available")
            

keyword=input("Enter product to search: ")
keyword=keyword.replace(" ","+")

url="https://www.flipkart.com/search?q="+keyword
urlA="https://www.amazon.in/s?k="+keyword


print("Connecting to amazon")
scrape(urlA)
print("Connecting to Flipkart")
scrape(url)
# Out:
# Enter product to search: samsung m52
# Connecting to amazon
# <ipython-input-85-4c30e75cf84b>:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path="C:\webdrivers\chromedriver.exe")
# -------------------------------------------------
# Samsung Galaxy M53 5G (Mystique Green, 6GB, 128GB Storage) | 108MP Camera | sAmoled+ 120Hz | 32MP Front Camera | 6nm Processor | 12GB RAM with RAM Plus | Travel Adapter to be Purchased Separately
# Samsung Galaxy M32 (Black, 6GB RAM, 128GB | FHD+ sAMOLED 90Hz Display | 6000mAh Battery | 64MP Quad Camera
# Samsung Galaxy M52 5G (Blazing Black, 6GB RAM, 128GB Storage) Latest Snapdragon 778G 5G | sAMOLED 120Hz Display
# Samsung Galaxy M52 5G (ICY Blue, 6GB RAM, 128GB Storage) Latest Snapdragon 778G 5G | sAMOLED 120Hz Display
# (Renewed) Samsung Galaxy M52 5G (ICY Blue, 6GB RAM, 128GB Storage) Latest Snapdragon 778G 5G | sAMOLED 120Hz Display
# (Renewed) Samsung Galaxy M52 5G (Blazing Black, 8GB RAM, 128GB Storage) Latest Snapdragon 778G 5G | sAMOLED 120Hz Display
# -------------------------------------------------
# ₹26,499
# ₹13,999
# ₹20,999
# ₹20,999
#
# ₹27,499
# -------------------------------------------------
# 3.8 out of 5 stars
# 4.1 out of 5 stars
# 4.2 out of 5 stars
# 4.2 out of 5 stars
# 3.2 out of 5 stars
# 3.2 out of 5 stars
# -------------------------------------------------
# 2,043
# 41,773
# 14,577
# 14,577
# 9
# 9
# Connecting to Flipkart
# -------------------------------------------------
# SAMSUNG Galaxy M52 5G (Icy Blue, 128 GB)
# SAMSUNG Galaxy M52 5G (Blazing Black, 128 GB)
# SAMSUNG GURU 1200
# SAMSUNG GURU 1200
# SAMSUNG Galaxy M52 5G (Icy Blue, 128 GB)
# SAMSUNG Galaxy A52 (Awesome Blue, 128 GB)
# -------------------------------------------------
# ₹24,243
# ₹23,362
# ₹1,750
# ₹1,650
# ₹23,484
# ₹25,490
# -------------------------------------------------
# 554 Ratings & 61 Reviews
# 945 Ratings & 106 Reviews
# 225 Ratings & 11 Reviews
# 567 Ratings & 42 Reviews
# 945 Ratings & 106 Reviews
# 1,815 Ratings & 228 Reviews
# -------------------------------------------------
# 4.2
# 4.2
# 4.2
# 3.9
# 4.2
# 4.3

# %%
df= pd.DataFrame(data)
df
# Out:
#                                          Product_Name            Price  \
# 0   Samsung Galaxy M53 5G (Mystique Green, 6GB, 12...          ₹26,499
# 1   Samsung Galaxy M32 (Black, 6GB RAM, 128GB | FH...          ₹13,999
# 2   Samsung Galaxy M52 5G (Blazing Black, 6GB RAM,...          ₹20,999
# 3   Samsung Galaxy M52 5G (ICY Blue, 6GB RAM, 128G...          ₹20,999
# 4   (Renewed) Samsung Galaxy M52 5G (ICY Blue, 6GB...  NO PRICE LISTED
# 5   (Renewed) Samsung Galaxy M52 5G (Blazing Black...          ₹27,499
# 6            SAMSUNG Galaxy M52 5G (Icy Blue, 128 GB)          ₹24,243
# 7       SAMSUNG Galaxy M52 5G (Blazing Black, 128 GB)          ₹23,362
# 8                                   SAMSUNG GURU 1200           ₹1,750
# 9                                   SAMSUNG GURU 1200           ₹1,650
# 10           SAMSUNG Galaxy M52 5G (Icy Blue, 128 GB)          ₹23,484
# 11          SAMSUNG Galaxy A52 (Awesome Blue, 128 GB)          ₹25,490
#
#                 Rating                      Reviews       Website
# 0   3.8 out of 5 stars                        2,043     AMAZON.IN
# 1   4.1 out of 5 stars                       41,773     AMAZON.IN
# 2   4.2 out of 5 stars                       14,577     AMAZON.IN
# 3   4.2 out of 5 stars                       14,577     AMAZON.IN
# 4   3.2 out of 5 stars                            9     AMAZON.IN
# 5   3.2 out of 5 stars                            9     AMAZON.IN
# 6                  4.2     554 Ratings & 61 Reviews  FLIPKART.COM
# 7                  4.2    945 Ratings & 106 Reviews  FLIPKART.COM
# 8                  4.2     225 Ratings & 11 Reviews  FLIPKART.COM
# 9                  3.9     567 Ratings & 42 Reviews  FLIPKART.COM
# 10                 4.2    945 Ratings & 106 Reviews  FLIPKART.COM
# 11                 4.3  1,815 Ratings & 228 Reviews  FLIPKART.COM

# %% [markdown]
# ## Flipkart

# %%
uClient=urlopen(url)
page_html=uClient.read()
uClient.close()
page_soup=soup(page_html,"html.parser")
container=page_soup.find_all("div",{"class":"_2kHMtA"})
con=container[0]
soup.prettify(con)
print("-------------------------------------------------")

for co in container:
    product_name=co.findAll("div",{"class":"_4rR01T"})
    print(product_name[0].text)
print("-------------------------------------------------")

for co in container:
    s_price=co.findAll("div",{"class":"_30jeq3 _1_WHN1"})
    print(s_price[0].text)
print("-------------------------------------------------")

for co in container:
    rating=co.findAll("span",{"class":"_2_R_DZ"})
    try:
         print(rating[0].text)
    except(IndexError):
        print()
print("-------------------------------------------------")

for co in container:
    star=co.findAll("div",{"class":"_3LWZlK"})
    try:
        print(star[0].text)
    except(IndexError):
        print()
# Out:
# -------------------------------------------------
# HP Pavilion Ryzen 5 Hexa Core 5600H - (8 GB/512 GB SSD/Windows 10/4 GB Graphics/NVIDIA GeForce GTX 165...
# HP Pavilion Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/Windows 10 Home) 14-ec0035AU Thin and Light Lap...
# HP Pavilion Core i5 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) 14-dv1000TU Thin and Light Laptop
# HP Pavilion Core i5 12th Gen - (16 GB/512 GB SSD/Windows 11 Home) EG2036TU Thin and Light Laptop
# HP Pavilion Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/Windows 10 Home) 15-eh1101AU Thin and Light Lap...
# HP Pavilion Core i5 12th Gen - (8 GB/512 GB SSD/Windows 11 Home) 15-EG2009TU Thin and Light Laptop
# HP Pavilion Core i5 11th Gen - (16 GB/512 GB SSD/Windows 11 Home) 14-dv1001TU Thin and Light Laptop
# HP Pavilion Core i7 12th Gen - (16 GB/1 TB SSD/Windows 11 Home) EG2039TU Thin and Light Laptop
# HP Pavilion Ryzen 5 Hexa Core 5625U - (8 GB/512 GB SSD/Windows 11 Home) 14-EC1003AU Thin and Light Lap...
# HP Pavilion Core i5 12th Gen - (16 GB/512 GB SSD/Windows 11 Home) EG2035TU Thin and Light Laptop
# HP Pavilion Ryzen 7 Octa Core 5825U - (16 GB/512 GB SSD/Windows 11 Home) 14-EC1008AU Thin and Light La...
# HP Pavilion Ryzen 5 Hexa Core 5625U - (16 GB/512 GB SSD/Windows 11 Home) 14-EC1019AU Thin and Light La...
# HP Pavilion Ryzen 7 Octa Core 5800H - (16 GB/512 GB SSD/Windows 10 Home/4 GB Graphics/NVIDIA GeForce R...
# HP Pavilion Ryzen 5 Hexa Core 5625U - (16 GB/512 GB SSD/Windows 11 Home) 15-eh2024AU Thin and Light La...
# HP Pavilion Ryzen 5 Hexa Core 5600H - (8 GB/512 GB SSD/Windows 10 Home/4 GB Graphics/NVIDIA GeForce GT...
# HP Pavilion Ryzen 5 Hexa Core 5500U - (16 GB/512 GB SSD/Windows 10 Home) 15-eh1103AU Thin and Light La...
# HP Pavilion Ryzen 5 Hexa Core 5500U - (16 GB/512 GB SSD/Windows 10 Home/2 GB Graphics) 14-ec0000AX Thi...
# HP Pavilion Core i5 11th Gen - (8 GB/512 GB SSD/Windows 10 Home) 15-eg0547TU Thin and Light Laptop
# HP Pavilion Core i7 11th Gen - (16 GB/512 GB SSD/Windows 11 Home) 14-dy1050TU Thin and Light Laptop
# HP Pavilion Core i7 11th Gen - (16 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/NVIDIA GeForce RTX RTX ...
# HP Pavilion Core i5 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) 15-eg1000TU Thin and Light Laptop
# HP Pavilion Ryzen 5 Hexa Core 5500U - (16 GB/512 GB SSD/Windows 10 Home) 14-ec0033AU Thin and Light La...
# HP Pavilion Ryzen 5 Hexa Core 5600H - (8 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/NVIDIA GeForce GT...
# HP Pavilion Core i5 11th Gen - (16 GB/512 GB SSD/Windows 11 Home) 14-dy1049TU Thin and Light Laptop
# -------------------------------------------------
# ₹60,990
# ₹54,990
# ₹57,890
# ₹73,190
# ₹54,999
# ₹64,990
# ₹65,990
# ₹87,490
# ₹54,990
# ₹73,190
# ₹71,999
# ₹62,988
# ₹90,990
# ₹62,990
# ₹73,544
# ₹59,990
# ₹63,990
# ₹62,990
# ₹88,190
# ₹87,990
# ₹63,990
# ₹59,990
# ₹72,990
# ₹75,190
# -------------------------------------------------
# 6,480 Ratings & 700 Reviews
# 433 Ratings & 59 Reviews
# 134 Ratings & 11 Reviews
#
# 130 Ratings & 20 Reviews
# 5 Ratings & 1 Reviews
# 227 Ratings & 18 Reviews
#
# 5 Ratings & 3 Reviews
#
# 4 Ratings & 0 Reviews
# 4 Ratings & 1 Reviews
# 280 Ratings & 40 Reviews
#
#
# 229 Ratings & 25 Reviews
# 107 Ratings & 15 Reviews
# 4 Ratings & 0 Reviews
#
# 13 Ratings & 4 Reviews
# 25 Ratings & 1 Reviews
# 26 Ratings & 3 Reviews
# 32 Ratings & 6 Reviews
#
# -------------------------------------------------
# 4.5
# 4.4
# 4.2
#
# 4.5
# 4.2
# 4.4
#
# 4.6
#
# 4.5
# 5
# 4.6
#
#
# 4.4
# 4.2
# 4.3
#
# 4.8
# 4.3
# 4.5
# 4.5

# %%
keyword=input("Enter product to search: ")
# Out:
# Enter product to search: hp omen

# %%
keyword=keyword.replace(" ","+")
keyword
# Out:
# 'hp+omen'
