# %%
from bs4 import BeautifulSoup as soup
import requests
from urllib.request import urlopen

# %%
import pandas as pd
import numpy as np

# %%
import csv
from selenium import webdriver

# %%
#keyword=input("Enter product to search: ")
# Out:
# Enter product to search: hp

# %%
#url="https://www.flipkart.com/search?q="+keyword
#urlA="https://www.amazon.in/s?k="+keyword

# %% [markdown]
# ## Amazon

# %%
def scrape(urlM):
    if urlM==urlA:
        driver=webdriver.Chrome(executable_path="D:\webdrivers\chromedriver.exe")
        driver.get(urlA)
        page_soupA=soup(driver.page_source,"html.parser")
        #print(page_soupA)
        containerA=page_soupA.find_all('div',{'data-component-type':"s-search-result"})
        conA=containerA[0]
        soup.prettify(conA)
        print("-------------------------------------------------")

        for co in containerA:
            atag=co.h2.a
            print(atag.text)
        print("-------------------------------------------------")

        for pr in containerA:
                prA=pr.find('span','a-price')

                try:
                    priceA=prA('span','a-offscreen')
                    print(priceA[0].text)

                except(TypeError):
                    print()
        print("-------------------------------------------------")

        for rat in containerA:
            try:
                rating=rat.i.text
                print(rating)
            except(AttributeError):
                print()

        print("-------------------------------------------------")
        for rew in containerA:
            try:
                rewC=rew.find('span',{'class':"a-size-base s-underline-text"})
                print(rewC.text)
            except(AttributeError):
                print()
    elif urlM==url:
        uClient=urlopen(url)
        page_html=uClient.read()
        uClient.close()
        page_soup=soup(page_html,"html.parser")
        container=page_soup.find_all("div",{"class":"_2kHMtA"})
        con=container[0]
        soup.prettify(con)
        print("-------------------------------------------------")

        for co in container:
            product_name=co.findAll("div",{"class":"_4rR01T"})
            print(product_name[0].text)
        print("-------------------------------------------------")

        for co in container:
            s_price=co.findAll("div",{"class":"_30jeq3 _1_WHN1"})
            print(s_price[0].text)
        print("-------------------------------------------------")

        for co in container:
            rating=co.findAll("span",{"class":"_2_R_DZ"})
            try:
                 print(rating[0].text)
            except(IndexError):
                print()
        print("-------------------------------------------------")

        for co in container:
            star=co.findAll("div",{"class":"_3LWZlK"})
            try:
                print(star[0].text)
            except(IndexError):
                print()

keyword=input("Enter product to search: ")
keyword=keyword.replace(" ","+")

url="https://www.flipkart.com/search?q="+keyword
urlA="https://www.amazon.in/s?k="+keyword


print("Connecting to amazon")
scrape(urlA)
print("Connecting to Flipkart")
scrape(url)
# Out:
# Enter product to search: dell xps
# Connecting to amazon
# C:\Users\chara\AppData\Local\Temp/ipykernel_3416/529845540.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path="D:\webdrivers\chromedriver.exe")
# -------------------------------------------------
# Fujitsu UH-X 11th Gen Intel Core i5 13.3” FHD IPS 400Nits Thin & Light Laptop(16GB/512GB SSD/Windows 11/Office 2021/Iris Xe Graphics/Backlit Kb/Fingerprint Reader/2Yr Warranty/Black/878gms),4ZR1F38022
# Fujitsu CH Intel Evo Core i5 11th Gen 13.3” FHD OLED 400Nits Thin & Light Laptop(16GB/512GB SSD/Windows 11/Office 2021/Iris Xe Graphics/Backlit/2Yr Warranty/Dark Grey/1.1Kg),4ZR1H03552
# Dell XPS 9305 13.3 inches FHD Display Thin & Light Laptop (Intel i5-1135G7 / 16GB / 512GB SSD / Integrated Graphics / Windows 10 + MSO / Backlit KB + FPR / Silver) D560053WIN9S, 1.16kg
# 2021 Newest Dell XPS 7590 15.6" 4K UHD Display, Intel Core I7-9750H, NVIDIA GTX 1650, 16GB RAM, 1TB PCIe SSD, Webcam, Backlit Keyboard, FP Reader, Windows 10 Home
# Dell 15 (2022)Intel I7-11800H, 16Gb/512Gb Ssd, Windows 11+Mso'21, Nvidia RTX 3050 Ti 4Gb, 15.6 Inches (39.61 Cms) Uhd+ Display, Platinum Silver (D560061Win9S, Xps 9510)
# Dell Inspiron 5406 11th Gen Intel i5-1135G7 14 inches FHD 2in1 Laptop (8GB / 512 SSD / Iris Xe Graphics /Windows 10/ MS Office 19/ Active Pen/Titan Grey),D560367WIN9S, 1.72kg
# Microsoft Surface Laptop Go 10th Gen Intel Coreâ„¢ i5-1035G1 12.4" (31.5 cms) Touchscreen Laptop (8GB/256GB SSD/Windows 10 Home in S Mode/Intel UHD Graphics/Platinum/1.110 kg)
# Lenovo IdeaPad Flex 5 11th Gen Intel Core i3 14 inches FHD IPS 2-in-1 Touchscreen Laptop(8GB/512GB SSD/Windows 10/MS Office/Lenovo Digital Pen/Fingerprint Reader/Graphite Grey/1.5Kg), 82HS009GIN
# -------------------------------------------------
# ₹64,500
# ₹73,990
# ₹2,25,000
# ₹1,05,399
# ₹1,05,990
# ₹89,890
#
# ₹1,10,000
# ₹1,45,000
# ₹88,999
# ₹49,936
# ₹1,28,490
# ₹1,19,999
# ₹1,40,000
# ₹1,10,004
# ₹1,17,900
#
# ₹2,75,589
# ₹2,24,999
# ₹65,000
# ₹84,099
# ₹56,990
# -------------------------------------------------
# 4.1 out of 5 stars
# 2.4 out of 5 stars
# 3.7 out of 5 stars
# 3.7 out of 5 stars
# 3.1 out of 5 stars
# 3.8 out of 5 stars
# 3.7 out of 5 stars
# 3.9 out of 5 stars
# 1.2 out of 5 stars
#
# 3.5 out of 5 stars
# 4.2 out of 5 stars
# 4.0 out of 5 stars
# 5.0 out of 5 stars
#
#
# 5.0 out of 5 stars
# 3.9 out of 5 stars
#
# 4.1 out of 5 stars
# 4.2 out of 5 stars
# 4.2 out of 5 stars
# -------------------------------------------------
# 89
# 9
# 22
# 20
# 11
# 10
# 22
# 15
# 9
#
# 40
# 39
# 1
# 1
#
#
# 1
# 17
#
# 221
# 101
# 155
# Connecting to Flipkart
# -------------------------------------------------
# DELL XPS Core i7 11th Gen - (16 GB/1 TB SSD/Windows 10) XPS 9310 Thin and Light Laptop
# DELL XPS Core i5 11th Gen - (16 GB/512 GB SSD/Windows 10) XPS 13 9305 Thin and Light Laptop
# DELL XPS Core i5 11th Gen Intel EVO - (8 GB/512 GB SSD/Windows 10 Home) XPS 9310 Thin and Light Laptop
# DELL XPS Core i5 10th Gen - (8 GB/512 GB SSD/Windows 10 Home) XPS 9300 Thin and Light Laptop
# DELL XPS Core i7 9th Gen - (8 GB/512 GB SSD/Windows 10 Home/4 GB Graphics) XPS 7590 Laptop
# DELL XPS 13 Core i7 8th Gen - (16 GB/512 GB SSD/Windows 10 Home) 9370 Thin and Light Laptop
# HP 1000 Wired Optical Mouse
# HP 100 Wired USB Desktop Keyboard
# DELL KB 216 Wired USB Desktop Keyboard
# ZEBRONICS Zeb-Judwaa 750 Keyboard & Mouse Combo Wired USB Desktop Keyboard
# ZEBRONICS JUDWAA 555 Combo Mouse and Wired USB Laptop Keyboard
# ZEBRONICS ZEB-KM-2100 Wired USB Desktop Keyboard
# HP C2500 Wired Combo keyboard and Mouse
# RAPOO N100 Wired Optical Mouse
# Razer Death Adder Essential Wired Optical  Gaming Mouse
# AMKETTE 398PP, Xcite NEO Wired USB Laptop Keyboard
# QUANTUM QHM7307 MINI MULTIMEDIA KEYBOARD Wired USB Multi-device Keyboard
# AMKETTE Xcite Neo Mouse & Wired USB Laptop Keyboard
# HP Y5G54PA#ACJ Wired USB Laptop Keyboard
# Zupero MFTEK Gaming Wired Mouse For PC and Laptops Wired Laser  Gaming Mouse
# ZEBRONICS Feather Wired Optical  Gaming Mouse
# Cosmic Byte CB-GK-05 Titan with Aluminum Body, Rainbow Backlit Keycaps, Braided Cable Wired USB Gaming...
# Lenovo KM4802 USB 2.0 Keyboard and Mouse Combo
# TVS Champ 2.0 Wired USB Desktop Keyboard
# Glink GLM69 Wired Optical Mouse
# LipiWorld High Sensitivity 2.4ghz 1600dpi Optical Wireless Mouse Wireless Optical Mouse
# Flipkart SmartBuy Dash Series G74 Gaming Mouse
# FU4 Portable Flexible Silicone Foldable Waterproof Wired USB Tablet Keyboard Wired USB Multi-device Ke...
# Dream ADNET USB Wired Optical Mouse
# HP M100 Wired Optical  Gaming Mouse
# Redgear MK881 Invador professional mechanical with Kailh blue switches, Lighting effect and windows ke...
# HyperX Alloy Core RGB (HX-KB5ME2-US) Membrane Wired USB Gaming Keyboard
# LAPCARE D-Lite+ Wired USB Desktop Keyboard
# XANOVA Magnetar with Cherry MX RGB Blue Switches Wired USB Gaming Keyboard
# TERABYTE vintage Wired Optical Mouse
# Lenovo Legion K200 Wired USB Gaming Keyboard
# Circle C-23 Wired USB Desktop Keyboard
# LipiWorld High Sensitivity 2.4ghz 1600dpi Optical Wireless Mouse Wireless Optical Mouse
# Razer BlackWidow Tournament Edition Chroma V2 Mechanical Yellow Switch Wired USB Gaming Keyboard
# ROQ FOLDABLE Wired USB Gaming Keyboard
# -------------------------------------------------
# ₹1,91,590
# ₹1,09,990
# ₹1,09,590
# ₹1,32,390
# ₹1,48,990
# ₹1,22,490
# ₹239
# ₹449
# ₹569
# ₹524
# ₹460
# ₹329
# ₹925
# ₹189
# ₹1,359
# ₹529
# ₹366
# ₹729
# ₹850
# ₹474
# ₹530
# ₹1,199
# ₹1,084
# ₹599
# ₹169
# ₹349
# ₹486
# ₹749
# ₹215
# ₹428
# ₹2,974
# ₹4,790
# ₹630
# ₹11,299
# ₹177
# ₹2,770
# ₹835
# ₹299
# ₹11,946
# ₹639
# -------------------------------------------------
#
#
#
#
#
# 3 Ratings & 0 Reviews
# 42,589 Ratings & 5,304 Reviews
# 10,382 Ratings & 1,407 Reviews
# 18,920 Ratings & 2,770 Reviews
# 8,560 Ratings & 1,023 Reviews
# 10,459 Ratings & 1,516 Reviews
# 12,540 Ratings & 1,690 Reviews
# 28,210 Ratings & 4,020 Reviews
# 392 Ratings & 76 Reviews
# 2,358 Ratings & 284 Reviews
# 15,920 Ratings & 2,656 Reviews
# 1,934 Ratings & 294 Reviews
# 8,822 Ratings & 1,533 Reviews
# 78 Ratings & 13 Reviews
# 1,541 Ratings & 250 Reviews
# 629 Ratings & 90 Reviews
# 2,005 Ratings & 348 Reviews
# 3,414 Ratings & 481 Reviews
# 141 Ratings & 21 Reviews
# 1,936 Ratings & 265 Reviews
# 11 Ratings & 1 Reviews
# 6,614 Ratings & 1,087 Reviews
# 140 Ratings & 13 Reviews
# 110 Ratings & 15 Reviews
# 12,119 Ratings & 1,735 Reviews
# 228 Ratings & 43 Reviews
# 249 Ratings & 37 Reviews
# 85 Ratings & 13 Reviews
#
# 56 Ratings & 5 Reviews
# 213 Ratings & 30 Reviews
# 152 Ratings & 19 Reviews
# 19 Ratings & 0 Reviews
# 15 Ratings & 2 Reviews
# 35 Ratings & 6 Reviews
# -------------------------------------------------
#
#
#
#
#
# 1.7
# 4.3
# 4.4
# 4.4
# 4.1
# 4
# 4
# 4.3
# 4.3
# 4.5
# 4.2
# 3.9
# 4.2
# 4.3
# 4.5
# 4.4
# 4.4
# 4.3
# 3.9
# 4
# 4.3
# 4.5
# 3.5
# 3.7
# 4.5
# 4.4
# 4.6
# 4
#
# 3.9
# 4.5
# 4.2
# 3.2
# 4.7
# 3.6

# %% [markdown]
# ## Flipkart

# %%
# uClient=urlopen(url)
# page_html=uClient.read()
# uClient.close()
# page_soup=soup(page_html,"html.parser")
# container=page_soup.find_all("div",{"class":"_2kHMtA"})
# con=container[0]
# soup.prettify(con)
# print("-------------------------------------------------")

# for co in container:
#     product_name=co.findAll("div",{"class":"_4rR01T"})
#     print(product_name[0].text)
# print("-------------------------------------------------")

# for co in container:
#     s_price=co.findAll("div",{"class":"_30jeq3 _1_WHN1"})
#     print(s_price[0].text)
# print("-------------------------------------------------")

# for co in container:
#     rating=co.findAll("span",{"class":"_2_R_DZ"})
#     try:
#          print(rating[0].text)
#     except(IndexError):
#         print()
# print("-------------------------------------------------")

# for co in container:
#     star=co.findAll("div",{"class":"_3LWZlK"})
#     try:
#         print(star[0].text)
#     except(IndexError):
#         print()

# %%
#keyword=input("Enter product to search: ")

# %%
#keyword=keyword.replace(" ","+")
#keyword
